# %%
from googleapiclient.discovery import build
import pandas as pd

# Data to be stored
category = []
no_of_samples = 1800

# Gathering Data using the Youtube API
api_key = "AIzaSyBNlM4z2-tcOjl0cSGVqIqwwuqfUA4Lb7k"
youtube_api = build('youtube','v3', developerKey = api_key)

# Travel Data
travel_titles = []
travel_descriptions = []
travel_ids = []

req = youtube_api.search().list(q='travel tips and scenery', part='snippet', type='video', maxResults = 50)
res = req.execute()
while(len(travel_titles)<no_of_samples):
    for i in range(len(res['items'])):
        travel_titles.append(res['items'][i]['snippet']['title'])
        travel_descriptions.append(res['items'][i]['snippet']['description'])
        travel_ids.append(res['items'][i]['id']['videoId'])
        category.append('travel')
            
    if('nextPageToken' in res):
        next_page_token = res['nextPageToken']
        req = youtube_api.search().list(q='travelling', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
        res = req.execute()
    else:
        break


# Comedy Data
comedy_titles = []
comedy_descriptions = []
comedy_ids = []

next_page_token = None
req = youtube_api.search().list(q='Comedy best of all time', part='snippet', type='video', maxResults = 50)
res = req.execute()
while(len(comedy_titles)<no_of_samples):
    if(next_page_token is not None):
        req = youtube_api.search().list(q='Comedy', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
        res = req.execute()
    for i in range(len(res['items'])):
        comedy_titles.append(res['items'][i]['snippet']['title'])
        comedy_descriptions.append(res['items'][i]['snippet']['description'])
        comedy_ids.append(res['items'][i]['id']['videoId'])
        category.append('Comedy')
            
    if('nextPageToken' in res):
        next_page_token = res['nextPageToken']
    else:
        break
    
# Food Data
food_titles = []
food_descriptions = []
food_ids = []

next_page_token = None
req = youtube_api.search().list(q='food cooking', part='snippet', type='video', maxResults = 50)
res = req.execute()
while(len(food_titles)<no_of_samples):
    if(next_page_token is not None):
        req = youtube_api.search().list(q='food cooking', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
        res = req.execute()
    for i in range(len(res['items'])):
        food_titles.append(res['items'][i]['snippet']['title'])
        food_descriptions.append(res['items'][i]['snippet']['description'])
        food_ids.append(res['items'][i]['id']['videoId'])
        category.append('food')
            
    if('nextPageToken' in res):
        next_page_token = res['nextPageToken']
    else:
        break

# Beauty Data
beauty_titles = []
beauty_descriptions = []
beauty_ids = []

next_page_token = None
req = youtube_api.search().list(q='Beauty get ready with me', part='snippet', type='video', maxResults = 50)
res = req.execute()
while(len(beauty_titles)<no_of_samples):
    if(next_page_token is not None):
        req = youtube_api.search().list(q='Beauty get ready with me', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
        res = req.execute()
    for i in range(len(res['items'])):
        beauty_titles.append(res['items'][i]['snippet']['title'])
        beauty_descriptions.append(res['items'][i]['snippet']['description'])
        beauty_ids.append(res['items'][i]['id']['videoId'])
        category.append('Beauty')
            
    if('nextPageToken' in res):
        next_page_token = res['nextPageToken']
    else:
        break
    
# Gaming Data
gaming_titles = []
gaming_descriptions = []
gaming_ids = []

next_page_token = None
req = youtube_api.search().list(q='Gaming funny streaming', part='snippet', type='video', maxResults = 50)
res = req.execute()
while(len(gaming_titles)<no_of_samples):
    if(next_page_token is not None):
        req = youtube_api.search().list(q='Gaming funny streaming', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
        res = req.execute()
    for i in range(len(res['items'])):
        gaming_titles.append(res['items'][i]['snippet']['title'])
        gaming_descriptions.append(res['items'][i]['snippet']['description'])
        gaming_ids.append(res['items'][i]['id']['videoId'])
        category.append('gaming')
            
    if('nextPageToken' in res):
        next_page_token = res['nextPageToken']
    else:
        break
    
# Fashion Data
fashion_titles = []
fashion_descriptions = []
fashion_ids = []

next_page_token = None
req = youtube_api.search().list(q='Fashion best of all time', part='snippet', type='video', maxResults = 50)
res = req.execute()
while(len(fashion_titles)<no_of_samples):
    if(next_page_token is not None):
        req = youtube_api.search().list(q='Fashion best of all time', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
        res = req.execute()
    for i in range(len(res['items'])):
        fashion_titles.append(res['items'][i]['snippet']['title'])
        fashion_descriptions.append(res['items'][i]['snippet']['description'])
        fashion_ids.append(res['items'][i]['id']['videoId'])
        category.append('fashion')
            
    if('nextPageToken' in res):
        next_page_token = res['nextPageToken']
    else:
        break
        
# DIY Data
diy_titles = []
diy_descriptions = []
diy_ids = []

next_page_token = None
req = youtube_api.search().list(q='DIY unique tips', part='snippet', type='video', maxResults = 50)
res = req.execute()
while(len(diy_titles)<no_of_samples):
    if(next_page_token is not None):
        req = youtube_api.search().list(q='DIY unique tips', part='snippet', type='video', maxResults = 50, pageToken=next_page_token)
        res = req.execute()
    for i in range(len(res['items'])):
        diy_titles.append(res['items'][i]['snippet']['title'])
        diy_descriptions.append(res['items'][i]['snippet']['description'])
        diy_ids.append(res['items'][i]['id']['videoId'])
        category.append('DIY')
            
    if('nextPageToken' in res):
        next_page_token = res['nextPageToken']
    else:
        break
 
    
# Construct Dataset
final_titles = travel_titles + comedy_titles + food_titles + beauty_titles + gaming_titles + fashion_titles + diy_titles
final_descriptions = travel_descriptions + comedy_descriptions + food_descriptions + beauty_descriptions + gaming_descriptions + fashion_descriptions + diy_descriptions
final_ids = travel_ids + comedy_ids + food_ids + beauty_ids + gaming_ids + fashion_ids + diy_ids
data = pd.DataFrame({'Video Id': final_ids, 'Title': final_titles, 'Description': final_descriptions, 'Category': category}) 
data.to_csv('Collected_data_raw3.csv')
